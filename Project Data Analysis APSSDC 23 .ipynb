# %% [markdown]
# # Read dataset

# %%
import pandas as pd
data=pd.read_csv("merged_files.csv")
data.head()
# Out:
#       Price  Area                         Location       City  \
# 0  30000000  3340                 JP Nagar Phase 1  Bangalore
# 1   7888000  1045       Dasarahalli on Tumkur Road  Bangalore
# 2   4866000  1179  Kannur on Thanisandra Main Road  Bangalore
# 3   8358000  1675                     Doddanekundi  Bangalore
# 4   6845000  1670                          Kengeri  Bangalore
#
#    No. of Bedrooms  Resale  24X7Security  CarParking  LiftAvailable  \
# 0                4       0             1           0              1
# 1                2       0             1           1              1
# 2                2       0             1           0              1
# 3                3       0             0           0              1
# 4                3       0             1           1              1
#
#    VaastuCompliant
# 0                0
# 1                1
# 2                0
# 3                0
# 4                0

# %%
data.shape
# Out:
# (32963, 10)

# %%
data.columns
# Out:
# Index(['Price', 'Area', 'Location', 'City', 'No. of Bedrooms', 'Resale',
#        '24X7Security', 'CarParking', 'LiftAvailable', 'VaastuCompliant'],
#       dtype='object')

# %% [markdown]
# # Data Filtering and cleaning

# %%
data.max()
# Out:
# Price                   854599999
# Area                        16000
# Location           worli sea face
# City                       Mumbai
# No. of Bedrooms                 9
# Resale                          1
# 24X7Security                    9
# CarParking                      9
# LiftAvailable                   9
# VaastuCompliant                 9
# dtype: object

# %%
data.min()
# Out:
# Price                        2000000
# Area                             200
# Location           1 Lane Johri Farm
# City                       Bangalore
# No. of Bedrooms                    1
# Resale                             0
# 24X7Security                       0
# CarParking                         0
# LiftAvailable                      0
# VaastuCompliant                    0
# dtype: object

# %%
data["City"].value_counts()
# Out:
# Mumbai       7719
# Kolkata      6507
# Bangalore    6207
# Chennai      5014
# Delhi        4998
# Hyderabad    2518
# Name: City, dtype: int64

# %%
#define Location
data.loc[(data["City"]=="Hyderabad")]
# Out:
#           Price  Area     Location       City  No. of Bedrooms  Resale  \
# 16219   6968000  1340     Nizampet  Hyderabad                2       0
# 16220  29000000  3498  Hitech City  Hyderabad                4       0
# 16221   6590000  1318    Manikonda  Hyderabad                2       0
# 16222   5739000  1295        Alwal  Hyderabad                3       1
# 16223   5679000  1145   Kukatpally  Hyderabad                2       0
# ...         ...   ...          ...        ...              ...     ...
# 18732  11000000  1460     Nacharam  Hyderabad                2       1
# 18733  26000000  1314    Manikonda  Hyderabad                2       1
# 18734  13300000  2625     Madhapur  Hyderabad                3       1
# 18735  10800000  2050  Hitech City  Hyderabad                3       0
# 18736  10400000  1805     Narsingi  Hyderabad                3       0
#
#        24X7Security  CarParking  LiftAvailable  VaastuCompliant
# ...

# %%
data.sort_values("Price").head()
# Out:
#          Price  Area         Location     City  No. of Bedrooms  Resale  \
# 15864  2000000   600      Uttam Nagar    Delhi                2       0
# 28263  2000000   780           Boisar   Mumbai                2       1
# 28262  2000000  1500  Jogeshwari West   Mumbai                3       1
# 28260  2000000   780           Boisar   Mumbai                2       1
# 22560  2000000  1900      New Alipore  Kolkata                4       0
#
#        24X7Security  CarParking  LiftAvailable  VaastuCompliant
# 15864             9           9              9                9
# 28263             9           9              9                9
# 28262             9           9              9                9
# 28260             9           9              9                9
# 22560             9           9              9                9

# %%
data.sort_values("Area").head()
# Out:
#          Price  Area           Location    City  No. of Bedrooms  Resale  \
# 12930  3300000   200  Sarvodaya Enclave   Delhi                1       1
# 28369  2900000   200         Malad West  Mumbai                1       0
# 28368  2800000   200         Malad West  Mumbai                1       1
# 12931  3300000   210  Sarvodaya Enclave   Delhi                1       1
# 30781  3600000   216         Vasai West  Mumbai                1       1
#
#        24X7Security  CarParking  LiftAvailable  VaastuCompliant
# 12930             0           0              0                0
# 28369             9           9              9                9
# 28368             9           9              9                9
# 12931             0           0              0                0
# 30781             9           9              9                9

# %%
data.sort_values("Price",ascending=False).head()
# Out:
#            Price  Area      Location   City  No. of Bedrooms  Resale  \
# 14414  854599999  6852   Vasant Kunj  Delhi                4       0
# 14415  854599999  5211  Sunder Nagar  Delhi                5       0
# 14324  748100000  7211         Saket  Delhi                5       0
# 15700  704400000  1490      West End  Delhi                3       1
# 14629  700000000  1400   Vasant Kunj  Delhi                3       1
#
#        24X7Security  CarParking  LiftAvailable  VaastuCompliant
# 14414             9           9              9                9
# 14415             9           9              9                9
# 14324             9           9              9                9
# 15700             9           9              9                9
# 14629             9           9              9                9

# %%
data.sort_values("Area",ascending=False).head()
# Out:
#            Price   Area         Location       City  No. of Bedrooms  Resale  \
# 13977   11200000  16000     Sainik Farms      Delhi                1       0
# 14325  285400000  12552  Prithviraj Road      Delhi                8       0
# 20687    2410000  10000         New Town    Kolkata                1       1
# 819    202700000   9900           Hebbal  Bangalore                5       0
# 817    198600000   9700           Hebbal  Bangalore                5       0
#
#        24X7Security  CarParking  LiftAvailable  VaastuCompliant
# 13977             9           9              9                9
# 14325             9           9              9                9
# 20687             9           9              9                9
# 819               1           1              0                0
# 817               1           1              0                0

# %%
data['No. of Bedrooms'].value_counts()
# Out:
# 2    14263
# 3    12596
# 1     3857
# 4     1983
# 5      214
# 6       33
# 7        9
# 8        7
# 9        1
# Name: No. of Bedrooms, dtype: int64

# %%
data[data["No. of Bedrooms"]==data["No. of Bedrooms"].max()]
# Out:
#          Price  Area      Location     City  No. of Bedrooms  Resale  \
# 22483  2400000  4800  Lake Gardens  Kolkata                9       0
#
#        24X7Security  CarParking  LiftAvailable  VaastuCompliant
# 22483             9           9              9                9

# %%
data.isnull().sum()
# Out:
# Price              0
# Area               0
# Location           0
# City               0
# No. of Bedrooms    0
# Resale             0
# 24X7Security       0
# CarParking         0
# LiftAvailable      0
# VaastuCompliant    0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Price              32963
# Area               32963
# Location           32963
# City               32963
# No. of Bedrooms    32963
# Resale             32963
# 24X7Security       32963
# CarParking         32963
# LiftAvailable      32963
# VaastuCompliant    32963
# dtype: int64

# %% [markdown]
# # Aggregations

# %%
#numrical data 
data1=data.copy()
num_data=data1.drop(columns={"Location","City"})
num_data.head()
# Out:
#       Price  Area  No. of Bedrooms  Resale  24X7Security  CarParking  \
# 0  30000000  3340                4       0             1           0
# 1   7888000  1045                2       0             1           1
# 2   4866000  1179                2       0             1           0
# 3   8358000  1675                3       0             0           0
# 4   6845000  1670                3       0             1           1
#
#    LiftAvailable  VaastuCompliant
# 0              1                0
# 1              1                1
# 2              1                0
# 3              1                0
# 4              1                0

# %%
num_data["Price"].mean()
# Out:
# 11686718.07605497

# %%
num_data["Price"].mode()
# Out:
# 0    4500000
# Name: Price, dtype: int64

# %%
num_data["Price"].median()
# Out:
# 6711000.0

# %%
num_data.describe()
# Out:
#               Price          Area  No. of Bedrooms        Resale  \
# count  3.296300e+04  32963.000000     32963.000000  32963.000000
# mean   1.168672e+07   1293.362194         2.411765      0.381397
# std    2.307368e+07    763.703754         0.812800      0.485737
# min    2.000000e+06    200.000000         1.000000      0.000000
# 25%    4.071500e+06    853.000000         2.000000      0.000000
# 50%    6.711000e+06   1125.000000         2.000000      0.000000
# 75%    1.200000e+07   1500.000000         3.000000      1.000000
# max    8.546000e+08  16000.000000         9.000000      1.000000
#
#        24X7Security    CarParking  LiftAvailable  VaastuCompliant
# count  32963.000000  32963.000000   32963.000000     32963.000000
# mean       6.382095      6.386767       6.463671         6.335497
# std        3.950395      3.943430       3.826128         4.018912
# min        0.000000      0.000000       0.000000         0.000000
# ...

# %% [markdown]
# # Grouping

# %%
gp_city=data.groupby("City")
gp_city.ngroups
# Out:
# 6

# %%
gp_city.get_group("Delhi")
# Out:
#           Price  Area          Location   City  No. of Bedrooms  Resale  \
# 11221  10500000  1200  Sector 10 Dwarka  Delhi                2       1
# 11222   6000000  1000       Uttam Nagar  Delhi                3       0
# 11223  15000000  1350      Sarita Vihar  Delhi                2       1
# 11224   2500000   435       Uttam Nagar  Delhi                2       0
# 11225   5800000   900        Dwarka Mor  Delhi                3       0
# ...         ...   ...               ...    ...              ...     ...
# 16214   2500000   540       Madhu Vihar  Delhi                2       1
# 16215   3000000   540       Madhu Vihar  Delhi                2       1
# 16216   2600000   415  Sector 26 Dwarka  Delhi                1       1
# 16217   5500000   415  Sector 26 Dwarka  Delhi                1       1
# 16218   4200000   900       Uttam Nagar  Delhi                3       1
#
#        24X7Security  CarParking  LiftAvailable  VaastuCompliant
# ...

# %%
Gp_beds=data.groupby("No. of Bedrooms")
Gp_beds.get_group(3)
# Out:
#           Price  Area                       Location       City  \
# 3       8358000  1675                   Doddanekundi  Bangalore
# 4       6845000  1670                        Kengeri  Bangalore
# 7       7105000  1438               Ramamurthy Nagar  Bangalore
# 8       8405000  1405  Whitefield Hope Farm Junction  Bangalore
# 11      9369000  1735                     Anjanapura  Bangalore
# ...         ...   ...                            ...        ...
# 32950   4250000   940               Ville Parle West     Mumbai
# 32951  10800000   940               Ville Parle West     Mumbai
# 32952  10800000   985               Ville Parle West     Mumbai
# 32953   2600000   985               Ville Parle West     Mumbai
# 32955   7200000  1250                  Borivali West     Mumbai
#
#        No. of Bedrooms  Resale  24X7Security  CarParking  LiftAvailable  \
# 3                    3       0             0           0              1
# ...

# %% [markdown]
# # Data visulization

# %%
import seaborn as sns

# %%
sns.kdeplot(num_data["No. of Bedrooms"])
sns.kdeplot(num_data["Resale"])
sns.kdeplot(num_data["CarParking"])
# Out:
# <Axes: xlabel='No. of Bedrooms', ylabel='Density'>

# %%
from sklearn.preprocessing import MinMaxScaler
mnscl=MinMaxScaler()
mnscl_d=mnscl.fit_transform(num_data)

# %%
mnscl_data=pd.DataFrame(mnscl_d,columns=num_data.columns)
mnscl_data.head()
# Out:
#       Price      Area  No. of Bedrooms  Resale  24X7Security  CarParking  \
# 0  0.032841  0.198734            0.375     0.0      0.111111    0.000000
# 1  0.006906  0.053481            0.125     0.0      0.111111    0.111111
# 2  0.003361  0.061962            0.125     0.0      0.111111    0.000000
# 3  0.007457  0.093354            0.250     0.0      0.000000    0.000000
# 4  0.005683  0.093038            0.250     0.0      0.111111    0.111111
#
#    LiftAvailable  VaastuCompliant
# 0       0.111111         0.000000
# 1       0.111111         0.111111
# 2       0.111111         0.000000
# 3       0.111111         0.000000
# 4       0.111111         0.000000

# %%
sns.kdeplot(mnscl_data["No. of Bedrooms"])
sns.kdeplot(mnscl_data["Resale"])
sns.kdeplot(mnscl_data["CarParking"])
# Out:
# <Axes: xlabel='No. of Bedrooms', ylabel='Density'>

# %%
mnscl_d.min()
# Out:
# 0.0

# %%
mnscl_d.max()
# Out:
# 1.0

# %%
sns.catplot(x="City",y="Price",data=data)

# %%
sns.catplot(x="Resale",y="Price",data=data)

# %%
sns.catplot(x="No. of Bedrooms",y="Price",data=data)

# %%
sns.catplot(x="No. of Bedrooms",y="City",data=data,kind="box")

# %%
sns.catplot(x="No. of Bedrooms",y="City",data=data,kind="violin")

# %%
sns.catplot(x="No. of Bedrooms",y="Price",data=data,kind="bar")

# %%
sns.catplot(x="No. of Bedrooms",y="Price",data=data,hue="Resale",kind="bar")

# %%
sns.jointplot(x="City",y="Price",data=data)

# %%
sns.jointplot(x="No. of Bedrooms",y="Price",data=data,color='g')

# %%
sns.pairplot(num_data)

# %%
sns.pairplot(num_data,hue="No. of Bedrooms")

# %%
sns.pairplot(num_data,hue="Resale")

# %%
sns.pairplot(num_data,vars=["Price","Area"])

# %%
num_data.corr()
# Out:
#                     Price      Area  No. of Bedrooms    Resale  24X7Security  \
# Price            1.000000  0.295062         0.163689  0.057410      0.041381
# Area             0.295062  1.000000         0.706007 -0.057304     -0.041710
# No. of Bedrooms  0.163689  0.706007         1.000000 -0.081430     -0.038476
# Resale           0.057410 -0.057304        -0.081430  1.000000      0.054250
# 24X7Security     0.041381 -0.041710        -0.038476  0.054250      1.000000
# CarParking       0.041293 -0.043253        -0.038415  0.056156      0.998477
# LiftAvailable    0.039589 -0.044236        -0.035475  0.053522      0.996836
# VaastuCompliant  0.039279 -0.043396        -0.036385  0.053369      0.997745
#
#                  CarParking  LiftAvailable  VaastuCompliant
# Price              0.041293       0.039589         0.039279
# Area              -0.043253      -0.044236        -0.043396
# No. of Bedrooms   -0.038415      -0.035475        -0.036385
# ...

# %%
sns.heatmap(num_data.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(num_data.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >
